# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from collections import Counter



df = pd.read_csv('Train_pass3_10cols.csv', parse_dates=True)
df.head(10)
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1263845      11000    1542938     3208         132           5.0      1919
# 1  1271235       8500    1393999     6633         132          15.0      1919
# 2  1284397      20000    1226376     3178         132          15.0      1919
# 3  1285083      20000    1346350     3178         132          15.0      1919
# 4  1288729      18000    1525079     3238         132          15.0      1919
# 5  1362939      15500    1227772     7267         132           6.0      1919
# 6  1363002      17000    1387642     7267         132           2.0      1919
# 7  1368428       8500    1283255     4146         132           7.0      1919
# 8  1369229      10500    1429950     4146         132           2.0      1919
# 9  1369230      16000    1479540     4146         132          24.0      1919
#
#         saledate ProductGroup Enclosure
# 0   4/18/98 0:00           BL     OROPS
# 1   4/13/11 0:00          SSL     OROPS
# 2  10/12/11 0:00           BL     OROPS
# 3  10/12/11 0:00           BL     OROPS
# 4   4/13/11 0:00          TTT     OROPS
# 5    3/2/95 0:00           WL     EROPS
# 6    2/7/00 0:00           WL     EROPS
# 7    3/7/07 0:00          TTT     OROPS
# 8   9/25/99 0:00          TTT     OROPS
# 9   8/12/99 0:00          TTT     OROPS

# %%
df.info()
#df.reset_index()
#df['AC'] = df[df['Enclosure']]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 362940 entries, 0 to 362939
# Data columns (total 10 columns):
# SalesID         362940 non-null int64
# SalePrice       362940 non-null int64
# MachineID       362940 non-null int64
# ModelID         362940 non-null int64
# datasource      362940 non-null int64
# auctioneerID    345366 non-null float64
# YearMade        362940 non-null int64
# saledate        362940 non-null object
# ProductGroup    362940 non-null object
# Enclosure       362685 non-null object
# dtypes: float64(1), int64(6), object(3)
# memory usage: 27.7+ MB

# %%
#df['YearSold'] = df['DateSold']

df['saledate'] = pd.to_datetime(df['saledate'])

df['saleyear'] = df['saledate'].dt.year
df['salemonth'] = df['saledate'].dt.month
#df.drop(columns=['YearSold'],inplace = True)

df.head()
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1263845      11000    1542938     3208         132           5.0      1919
# 1  1271235       8500    1393999     6633         132          15.0      1919
# 2  1284397      20000    1226376     3178         132          15.0      1919
# 3  1285083      20000    1346350     3178         132          15.0      1919
# 4  1288729      18000    1525079     3238         132          15.0      1919
#
#     saledate ProductGroup Enclosure  saleyear  salemonth
# 0 1998-04-18           BL     OROPS      1998          4
# 1 2011-04-13          SSL     OROPS      2011          4
# 2 2011-10-12           BL     OROPS      2011         10
# 3 2011-10-12           BL     OROPS      2011         10
# 4 2011-04-13          TTT     OROPS      2011          4

# %%
#df.dropna(inplace=True)
df.info()
Counter(df.ProductGroup)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 362940 entries, 0 to 362939
# Data columns (total 12 columns):
# SalesID         362940 non-null int64
# SalePrice       362940 non-null int64
# MachineID       362940 non-null int64
# ModelID         362940 non-null int64
# datasource      362940 non-null int64
# auctioneerID    345366 non-null float64
# YearMade        362940 non-null int64
# saledate        362940 non-null datetime64[ns]
# ProductGroup    362940 non-null object
# Enclosure       362685 non-null object
# saleyear        362940 non-null int64
# salemonth       362940 non-null int64
# dtypes: datetime64[ns](1), float64(1), int64(8), object(2)
# memory usage: 33.2+ MB
# Counter({'BL': 74615,
#          'MG': 22641,
#          'SSL': 39482,
#          'TEX': 88529,
#          'TTT': 73455,
#          'WL': 64218})

# %%
df.groupby('ProductGroup').mean()
# Out:
#                    SalesID     SalePrice     MachineID       ModelID  \
# ProductGroup
# BL            1.835075e+06  21229.234108  1.249628e+06   5361.512685
# MG            1.840781e+06  49566.169471  1.162381e+06   7320.708979
# SSL           2.056529e+06  10701.891039  1.275930e+06  10465.944861
# TEX           2.008122e+06  37690.883496  1.201414e+06   7809.703837
# TTT           1.857726e+06  37586.693241  1.150703e+06   5356.358655
# WL            1.900488e+06  38420.446074  1.216930e+06   6155.224828
#
#               datasource  auctioneerID     YearMade     saleyear  salemonth
# ProductGroup
# BL            134.422435      6.946548  1995.364525  2003.779656   6.556175
# MG            134.501789      7.454354  1985.300473  2002.911930   6.231483
# SSL           135.259359      6.128482  1999.531559  2005.769996   6.576997
# TEX           135.230625      5.477695  1996.690508  2004.856058   6.420167
# TTT           134.652835      7.147664  1990.685358  2002.950922   6.412130
# WL            134.901601      6.383828  1990.792114  2003.446246   6.276651

# %%
df['PGNum'] = df['ProductGroup']


df.head()

Counter(df.PGNum)
df.head()
#df.to_csv('0708_industry_mach_dfpass2_1.csv')
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1263845      11000    1542938     3208         132           5.0      1919
# 1  1271235       8500    1393999     6633         132          15.0      1919
# 2  1284397      20000    1226376     3178         132          15.0      1919
# 3  1285083      20000    1346350     3178         132          15.0      1919
# 4  1288729      18000    1525079     3238         132          15.0      1919
#
#     saledate ProductGroup Enclosure  saleyear  salemonth PGNum
# 0 1998-04-18           BL     OROPS      1998          4    BL
# 1 2011-04-13          SSL     OROPS      2011          4   SSL
# 2 2011-10-12           BL     OROPS      2011         10    BL
# 3 2011-10-12           BL     OROPS      2011         10    BL
# 4 2011-04-13          TTT     OROPS      2011          4   TTT

# %%
def PGconv(df):
    if df['PGNum'] == 'SSL':
        return 10000
    elif df['PGNum'] == 'BL':
        return 21000
    elif df['PGNum'] == 'TEX':
        return 37700
    elif df['PGNum'] == 'TTT':
        return 37600
    elif df['PGNum'] == 'WL':
        return 38400
    elif df['PGNum'] == 'MG':
        return 49500
    else: 
        return 0
    
df['PGNum'] = df.apply(PGconv, axis=1)

#df.reset_index(inplace = True)

#df.drop(columns=['level_0'],inplace = True)
df.head(10)
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1263845      11000    1542938     3208         132           5.0      1919
# 1  1271235       8500    1393999     6633         132          15.0      1919
# 2  1284397      20000    1226376     3178         132          15.0      1919
# 3  1285083      20000    1346350     3178         132          15.0      1919
# 4  1288729      18000    1525079     3238         132          15.0      1919
# 5  1362939      15500    1227772     7267         132           6.0      1919
# 6  1363002      17000    1387642     7267         132           2.0      1919
# 7  1368428       8500    1283255     4146         132           7.0      1919
# 8  1369229      10500    1429950     4146         132           2.0      1919
# 9  1369230      16000    1479540     4146         132          24.0      1919
#
#     saledate ProductGroup Enclosure  saleyear  salemonth  PGNum
# 0 1998-04-18           BL     OROPS      1998          4  21000
# 1 2011-04-13          SSL     OROPS      2011          4  10000
# 2 2011-10-12           BL     OROPS      2011         10  21000
# 3 2011-10-12           BL     OROPS      2011         10  21000
# 4 2011-04-13          TTT     OROPS      2011          4  37600
# 5 1995-03-02           WL     EROPS      1995          3  38400
# 6 2000-02-07           WL     EROPS      2000          2  38400
# 7 2007-03-07          TTT     OROPS      2007          3  37600
# 8 1999-09-25          TTT     OROPS      1999          9  37600
# 9 1999-08-12          TTT     OROPS      1999          8  37600

# %%
Counter(df.Enclosure)
# Out:
# Counter({'EROPS': 121622,
#          'EROPS AC': 15,
#          'EROPS w AC': 82059,
#          'NO ROPS': 2,
#          'None or Unspecified': 2,
#          'OROPS': 158985,
#          nan: 255})

# %%
df['EnclosureNum'] = df['Enclosure']
#df.head()

# %%
def Enclconv(df):
    if df['EnclosureNum'] == 'EROPS':
        return 30000
    elif df['EnclosureNum'] == 'EROPS AC':
        return 26000
    elif df['EnclosureNum'] == 'EROPS w AC':
        return 53000
    elif df['EnclosureNum'] == 'NO ROPS':
        return 45000
    elif df['EnclosureNum'] == 'OROPS':
        return 23000
    elif df['EnclosureNum'] == 'Unspecified':
        return 16000
    elif df['EnclosureNum'] == 'None':
        return 16000
    else: 
        return 0
    
df['EnclosureNum'] = df.apply(Enclconv, axis=1)

# %%
df.head()
# Out:
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1263845      11000    1542938     3208         132           5.0      1919
# 1  1271235       8500    1393999     6633         132          15.0      1919
# 2  1284397      20000    1226376     3178         132          15.0      1919
# 3  1285083      20000    1346350     3178         132          15.0      1919
# 4  1288729      18000    1525079     3238         132          15.0      1919
#
#     saledate ProductGroup Enclosure  saleyear  salemonth  PGNum  EnclosureNum
# 0 1998-04-18           BL     OROPS      1998          4  21000         23000
# 1 2011-04-13          SSL     OROPS      2011          4  10000         23000
# 2 2011-10-12           BL     OROPS      2011         10  21000         23000
# 3 2011-10-12           BL     OROPS      2011         10  21000         23000
# 4 2011-04-13          TTT     OROPS      2011          4  37600         23000

# %%
#df.groupby('Enclosure').mean()
df.groupby('Enclosure').max()
# Out:
#                      SalesID  SalePrice  MachineID  ModelID  datasource  \
# Enclosure
# EROPS                6333342     141000    2386738    37197         172
# EROPS AC             4309299      61000    2272832    22057         172
# EROPS w AC           6333223     142000    2386411    37198         172
# NO ROPS              2252300      48000    1464611     4147         136
# None or Unspecified  1586735      19000    1259439     4725         132
# OROPS                6331841     140000    2486276    37197         172
#
#                      auctioneerID  YearMade   saledate ProductGroup  saleyear  \
# Enclosure
# EROPS                        99.0      2010 2011-12-30           WL      2011
# EROPS AC                     28.0      2004 2011-08-10           WL      2011
# EROPS w AC                   99.0      2013 2011-12-30           WL      2011
# NO ROPS                       6.0      1982 2010-04-22          TTT      2010
# None or Unspecified           2.0      1995 2007-09-19          TEX      2007
# OROPS                        99.0      2012 2011-12-30           WL      2011
#
#                      salemonth  PGNum  EnclosureNum
# Enclosure
# EROPS                       12  49500         30000
# EROPS AC                    12  49500         26000
# EROPS w AC                  12  49500         53000
# NO ROPS                      4  37600         45000
# None or Unspecified         11  37700             0
# OROPS                       12  49500         23000

# %%
#Counter(df.PGNum)
#Counter(df.ModelID)
#df.info()
dfpass2 = df
dfpass2.head()
#pd.to_numeric(dfnum1['fiBaseModel'], errors='coerce')

dfpass2.info()
#dfpass2.to_csv('0708_industry_mach_reg_dfpass2_2converts.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 362940 entries, 0 to 362939
# Data columns (total 14 columns):
# SalesID         362940 non-null int64
# SalePrice       362940 non-null int64
# MachineID       362940 non-null int64
# ModelID         362940 non-null int64
# datasource      362940 non-null int64
# auctioneerID    345366 non-null float64
# YearMade        362940 non-null int64
# saledate        362940 non-null datetime64[ns]
# ProductGroup    362940 non-null object
# Enclosure       362685 non-null object
# saleyear        362940 non-null int64
# salemonth       362940 non-null int64
# PGNum           362940 non-null int64
# EnclosureNum    362940 non-null int64
# dtypes: datetime64[ns](1), float64(1), int64(10), object(2)
# memory usage: 38.8+ MB

# %%
#dfpass2.drop(columns=['auctioneerID'],inplace = True)
#dfpass2.drop(columns=['ProductGroup'],inplace = True)
#dfpass2.drop(columns=['Enclosure'],inplace = True)
#dfpass2.drop(columns=['saledate'],inplace = True)
dfpass2.head()
dfpass2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 362940 entries, 0 to 362939
# Data columns (total 10 columns):
# SalesID         362940 non-null int64
# SalePrice       362940 non-null int64
# MachineID       362940 non-null int64
# ModelID         362940 non-null int64
# datasource      362940 non-null int64
# YearMade        362940 non-null int64
# saleyear        362940 non-null int64
# salemonth       362940 non-null int64
# PGNum           362940 non-null int64
# EnclosureNum    362940 non-null int64
# dtypes: int64(10)
# memory usage: 27.7 MB

# %%
#dfpass3 = dfpass2

#dfpass2.drop(columns=['auctioneerID'],inplace = True)
#dfpass2.to_csv('0708_industry_mach_reg_dfpass2_3allnumeric.csv')
dfpass2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 362940 entries, 0 to 362939
# Data columns (total 10 columns):
# SalesID         362940 non-null int64
# SalePrice       362940 non-null int64
# MachineID       362940 non-null int64
# ModelID         362940 non-null int64
# datasource      362940 non-null int64
# YearMade        362940 non-null int64
# saleyear        362940 non-null int64
# salemonth       362940 non-null int64
# PGNum           362940 non-null int64
# EnclosureNum    362940 non-null int64
# dtypes: int64(10)
# memory usage: 27.7 MB

# %%
y = dfpass2['SalePrice'].values
X = dfpass2[['SalesID','MachineID','ModelID','datasource','YearMade','saleyear','salemonth','PGNum','EnclosureNum']].values
#'fiModelDesc','fiBaseModel','salemonth','Enclosure','AC','PGNum'

X = sm.add_constant(X)
#beta = np.linalg.solve(X.T.dot(X), X.T.dot(y))
#beta

model = sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.461
# Model:                            OLS   Adj. R-squared:                  0.461
# Method:                 Least Squares   F-statistic:                 3.446e+04
# Date:                Sun, 08 Jul 2018   Prob (F-statistic):               0.00
# Time:                        10:20:22   Log-Likelihood:            -4.0547e+06
# No. Observations:              362940   AIC:                         8.109e+06
# Df Residuals:                  362930   BIC:                         8.109e+06
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -4.653e+04   1.14e+04     -4.064      0.000    -6.9e+04   -2.41e+04
# x1         -6.164e-05    5.4e-05     -1.142      0.253      -0.000    4.41e-05
# x2            -0.0067   6.93e-05    -97.369      0.000      -0.007      -0.007
# x3            -0.1856      0.005    -38.104      0.000      -0.195      -0.176
# x4           116.7649      5.217     22.383      0.000     106.540     126.990
# x5          1054.9518      4.163    253.428      0.000    1046.793    1063.111
# x6         -1037.3042      6.826   -151.954      0.000   -1050.684   -1023.925
# x7          -200.0551      8.433    -23.723      0.000    -216.583    -183.527
# x8             0.9558      0.003    314.010      0.000       0.950       0.962
# x9             0.5782      0.003    207.319      0.000       0.573       0.584
# ==============================================================================
# Omnibus:                    68009.370   Durbin-Watson:                   0.888
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           164485.614
# Skew:                           1.053   Prob(JB):                         0.00
# Kurtosis:                       5.538   Cond. No.                     9.77e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.77e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

#df_x --> new dataframe of independent variables
df_x = dfpass2.drop(['SalePrice'], 1)

#df_y --> new dataframe of dependent variable views
df_y = dfpass2.ix[:, ['SalePrice']]

names = [i for i in list(df_x)]

regr = LinearRegression()
x_train, x_test, y_train, y_test = train_test_split(df_x, df_y, test_size = 0.2)

#Fitting the model to the training dataset
regr.fit(x_train,y_train)
regr.intercept_
print('Coefficients: \n', regr.coef_)
print("Mean Squared Error(MSE): %.2f"
     % np.mean((regr.predict(x_test) - y_test) ** 2))
print('Variance Score: %.2f' % regr.score(x_test, y_test))
regr.coef_[0].tolist()
# Out:
# Coefficients:
#  [[-2.07050149e-05 -6.75484947e-03 -1.87280298e-01  1.16084026e+02
#    1.05743356e+03 -1.04001251e+03 -2.03175077e+02  9.57433280e-01
#    5.77250891e-01]]
# Mean Squared Error(MSE): 298205077.94
# Variance Score: 0.46
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   if __name__ == '__main__':
# [-2.0705014949330466e-05,
#  -0.006754849467293639,
#  -0.18728029752254752,
#  116.08402585278893,
#  1057.4335566790471,
#  -1040.0125100696766,
#  -203.17507704673167,
#  0.9574332803470881,
#  0.5772508913288802]

# %%
import statsmodels.api as sm
from statsmodels.sandbox.regression.predstd import wls_prediction_std
model=sm.OLS(y_train,x_train)
result = model.fit()
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.814
# Model:                            OLS   Adj. R-squared:                  0.814
# Method:                 Least Squares   F-statistic:                 1.409e+05
# Date:                Sun, 08 Jul 2018   Prob (F-statistic):               0.00
# Time:                        10:20:36   Log-Likelihood:            -3.2435e+06
# No. Observations:              290352   AIC:                         6.487e+06
# Df Residuals:                  290343   BIC:                         6.487e+06
# Df Model:                           9
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# SalesID       5.335e-05   5.66e-05      0.942      0.346   -5.76e-05       0.000
# MachineID       -0.0068   7.72e-05    -87.753      0.000      -0.007      -0.007
# ModelID         -0.1856      0.005    -34.246      0.000      -0.196      -0.175
# datasource     114.4846      5.808     19.713      0.000     103.102     125.867
# YearMade      1056.2560      4.642    227.550      0.000    1047.158    1065.354
# saleyear     -1061.7610      4.659   -227.900      0.000   -1070.892   -1052.630
# salemonth     -206.1459      9.387    -21.961      0.000    -224.544    -187.748
# PGNum            0.9552      0.003    285.613      0.000       0.949       0.962
# EnclosureNum     0.5798      0.003    191.241      0.000       0.574       0.586
# ==============================================================================
# Omnibus:                    54210.972   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           130885.884
# Skew:                           1.050   Prob(JB):                         0.00
# Kurtosis:                       5.531   Cond. No.                     7.18e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.18e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
